# %% [markdown]
# ##### 1. 安装Segmentation和相关依赖库

# %%
"""
Package                    Version      Location
-------------------------- ------------ -----------------------------------------
absl-py                    1.0.0
addict                     2.4.0
albumentations             1.3.0
argon2-cffi                21.3.0
argon2-cffi-bindings       21.2.0
attrs                      21.4.0
backcall                   0.2.0
beautifulsoup4             4.10.0
black                      22.1.0
bleach                     4.1.0
brotlipy                   0.7.0
cachetools                 5.0.0
ccimport                   0.3.7
certifi                    2021.10.8
cffi                       1.15.0
chardet                    4.0.0
charset-normalizer         2.0.4
chumpy                     0.70
click                      8.0.4
colorama                   0.4.4
conda                      4.12.0
conda-build                3.21.7
conda-content-trust        0+unknown
conda-package-handling     1.8.0
coverage                   6.3.2
cryptography               36.0.0
cumm                       0.3.0        /cumm
cumm-cu113                 0.2.8
cupy-cuda113               10.3.1
cycler                     0.11.0
Cython                     0.29.28
debugpy                    1.6.0
decorator                  5.1.1
defusedxml                 0.7.1
descartes                  1.1.0
dnspython                  2.2.1
einops                     0.6.1
entrypoints                0.4
fastrlock                  0.8
filelock                   3.6.0
fire                       0.4.0
flake8                     4.0.1
flatbuffers                2.0
fonttools                  4.31.2
fsspec                     2023.5.0
glob2                      0.7
google-auth                2.6.2
google-auth-oauthlib       0.4.6
grad-cam                   1.4.6
grpcio                     1.44.0
gviz-api                   1.10.0
huggingface-hub            0.14.1
idna                       3.3
imageio                    2.15.0
importlib-metadata         4.11.3
importlib-resources        5.6.0
iniconfig                  1.1.1
install                    1.3.5
ipykernel                  6.9.2
ipython                    7.31.1
ipython-genutils           0.2.0
ipywidgets                 7.7.0
jedi                       0.18.1
Jinja2                     2.11.3
joblib                     1.1.0
json-tricks                3.16.1
jsonschema                 4.4.0
jupyter                    1.0.0
jupyter-client             7.1.2
jupyter-console            6.4.3
jupyter-core               4.9.2
jupyterlab-pygments        0.1.2
jupyterlab-widgets         1.1.0
kiwisolver                 1.4.1
lark                       1.1.2
libarchive-c               2.9
llvmlite                   0.36.0
lmdb                       1.3.0
lyft-dataset-sdk           0.0.8
Markdown                   3.3.6
markdown-it-py             2.2.0
MarkupSafe                 2.0.1
mat4py                     0.5.0
matplotlib                 3.5.1
matplotlib-inline          0.1.2
mccabe                     0.6.1
mdurl                      0.1.2
mistune                    0.8.4
mkl-fft                    1.3.1
mkl-random                 1.2.2
mkl-service                2.4.0
mmcls                      0.21.0
mmcv                       2.0.0rc4     /opt/conda/lib/python3.8/site-packages
mmcv-full                  1.7.1        /opt/conda/lib/python3.8/site-packages
mmdet                      3.0.0        /workspace/openmmhomework3/mmdetection
mmengine                   0.7.3
mmpretrain                 1.0.0rc8     /workspace/openmmhomework2/mmpretrain
mmsegmentation             1.0.0        /workspace/openmmhomework4/mmsegmentation
mmyolo                     0.6.0        /workspace/openmmhomework3/mmyolo
model-index                0.1.11
modelindex                 0.0.2
munkres                    1.1.4
mypy-extensions            0.4.3
nbclient                   0.5.13
nbconvert                  6.4.4
nbformat                   5.2.0
nest-asyncio               1.5.4
networkx                   2.2
ninja                      1.10.2.3
notebook                   6.4.10
numba                      0.53.0
numpy                      1.23.5
nuscenes-devkit            1.1.9
oauthlib                   3.2.0
onnx                       1.7.0
onnxoptimizer              0.2.6
onnxruntime                1.11.0
opencv-python              4.5.5.64
opencv-python-headless     4.7.0.72
openmim                    0.3.7
ordered-set                4.1.0
packaging                  21.3
pandas                     1.4.1
pandocfilters              1.5.0
parso                      0.8.3
pathspec                   0.9.0
pccm                       0.3.4
pexpect                    4.8.0
pickleshare                0.7.5
Pillow                     9.0.1
pip                        21.2.4
pkginfo                    1.8.2
platformdirs               2.5.1
plotly                     5.6.0
pluggy                     1.0.0
plyfile                    0.7.4
portalocker                2.4.0
prettytable                3.2.0
prometheus-client          0.13.1
prompt-toolkit             3.0.20
protobuf                   3.19.4
psutil                     5.8.0
ptyprocess                 0.7.0
py                         1.11.0
pyasn1                     0.4.8
pyasn1-modules             0.2.8
pybind11                   2.9.2
pycocotools                2.0.4
pycodestyle                2.8.0
pycosat                    0.6.3
pycparser                  2.21
pyflakes                   2.4.0
Pygments                   2.15.1
pyOpenSSL                  22.0.0
pyparsing                  3.0.7
pyquaternion               0.9.9
pyrsistent                 0.18.1
PySocks                    1.7.1
pytest                     7.1.1
pytest-runner              6.0.0
python-dateutil            2.8.2
python-etcd                0.4.5
PyTurboJPEG                1.6.6
pytz                       2021.3
PyWavelets                 1.3.0
PyYAML                     6.0
pyzmq                      22.3.0
qtconsole                  5.2.2
QtPy                       2.0.1
qudida                     0.0.4
regex                      2023.5.5
requests                   2.27.1
requests-oauthlib          1.3.1
rich                       13.3.5
rsa                        4.8
ruamel-yaml-conda          0.15.100
scikit-image               0.19.2
scikit-learn               1.0.2
scipy                      1.8.0
seaborn                    0.12.2
Send2Trash                 1.8.0
setuptools                 58.0.4
Shapely                    1.8.1.post1
SharedArray                3.2.1
six                        1.16.0
soupsieve                  2.3.1
spconv                     2.1.21       /spconv
tabulate                   0.9.0
tenacity                   8.0.1
tensorboard                2.8.0
tensorboard-data-server    0.6.1
tensorboard-plugin-profile 2.8.0
tensorboard-plugin-wit     1.8.1
termcolor                  1.1.0
terminado                  0.13.3
terminaltables             3.1.10
testpath                   0.6.0
threadpoolctl              3.1.0
tifffile                   2022.3.25
tokenizers                 0.13.3
tomli                      2.0.1
torch                      1.10.1+cu113
torch-tb-profiler          0.4.0
torchaudio                 0.10.1+cu113
torchelastic               0.2.2
torchvision                0.11.2+cu113
tornado                    6.1
tqdm                       4.63.0
traitlets                  5.1.1
transformers               4.29.1
trimesh                    2.35.39
ttach                      0.0.3
typing_extensions          4.5.0
urllib3                    1.26.8
wcwidth                    0.2.5
webencodings               0.5.1
Werkzeug                   2.0.3
wheel                      0.37.1
widgetsnbextension         3.6.0
xtcocotools                1.13
yapf                       0.32.0
zipp                       3.7.0"""
# Out:
# '\nPackage                    Version      Location\n-------------------------- ------------ -----------------------------------------\nabsl-py                    1.0.0\naddict                     2.4.0\nalbumentations             1.3.0\nargon2-cffi                21.3.0\nargon2-cffi-bindings       21.2.0\nattrs                      21.4.0\nbackcall                   0.2.0\nbeautifulsoup4             4.10.0\nblack                      22.1.0\nbleach                     4.1.0\nbrotlipy                   0.7.0\ncachetools                 5.0.0\nccimport                   0.3.7\ncertifi                    2021.10.8\ncffi                       1.15.0\nchardet                    4.0.0\ncharset-normalizer         2.0.4\nchumpy                     0.70\nclick                      8.0.4\ncolorama                   0.4.4\nconda                      4.12.0\nconda-build                3.21.7\nconda-content-trust        0+unknown\nconda-package-handling     1.8.0\ncoverage                   6.3.
# ...

# %% [markdown]
# ##### 2. 探索数据集

# %%
# !pwd
# Out:
# /workspace/openmmhomework4

# %%
import os
os.chdir('mmsegmentation')

# %%
import os

import cv2
import numpy as np
from PIL import Image
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 指定单张图像路径
img_path = '/workspace/openmmhomework4/mmsegmentation/data/Watermelon87_Semantic_Seg_Mask/img_dir/train/04_35-2.jpg'
mask_path = '/workspace/openmmhomework4/mmsegmentation/data/Watermelon87_Semantic_Seg_Mask/ann_dir/train/04_35-2.png'

# %%
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x668 at 0x7F6D46C9B850>

# %%
Image.open(mask_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1000x668 at 0x7F6D95EC5A00>

# %%
img = cv2.imread(img_path)
mask = cv2.imread(mask_path)
print('img shape: ', img.shape)
print('mask shape: ', mask.shape)
# Out:
# img shape:  (668, 1000, 3)
# mask shape:  (668, 1000, 3)

# %%
# mask 语义分割标注，与原图大小相同
np.unique(mask)
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=uint8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 可视化语义分割标注
plt.imshow(mask[:,:,0])
plt.show()

# %%
# 叠加在原图上
plt.imshow(img[:,:,::-1]) # ::-1 换RGB通道顺序
plt.imshow(mask[:,:,0], alpha=0.4) # alpha 高亮区域透明度，越小越接近原图
plt.axis('off')
plt.show()

# %%
# 批量可视化
# 指定图像和标注路径
PATH_IMAGE = '/workspace/openmmhomework4/mmsegmentation/data/Watermelon87_Semantic_Seg_Mask/img_dir/train'
PATH_MASKS = '/workspace/openmmhomework4/mmsegmentation/data/Watermelon87_Semantic_Seg_Mask/ann_dir/train'

# %%
# n行n列可视化
n = 5

# 标注区域透明度
opacity = 0.5

fig, axes = plt.subplots(nrows=n, ncols=n, sharex=True, figsize=(12,12))

for i, file_name in enumerate(os.listdir(PATH_IMAGE)[:n**2]):
    
    # 载入图像和标注
    img_path = os.path.join(PATH_IMAGE, file_name)
    mask_path = os.path.join(PATH_MASKS, file_name.split('.')[0]+'.png')
    img = cv2.imread(img_path)
    mask = cv2.imread(mask_path)
    
    # 可视化
    axes[i//n, i%n].imshow(img[:,:,::-1])
    axes[i//n, i%n].imshow(mask[:,:,0], alpha=opacity)
    axes[i//n, i%n].axis('off') # 关闭坐标轴显示
fig.suptitle('Image and Semantic Label', fontsize=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3. 配置Config

# %%
os.getcwd()
# Out:
# '/workspace/openmmhomework4/mmsegmentation'

# %%
# 导入工具包
import numpy as np
from PIL import Image

import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !rm -rf mmseg/datasets/DubaiDataset.py # 删除原有文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/DubaiDataset.py -P mmseg/datasets
# Out:
# --2023-06-14 02:58:28--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/DubaiDataset.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 867 [binary/octet-stream]
# Saving to: ‘mmseg/datasets/DubaiDataset.py’
#
# DubaiDataset.py     100%[===================>]     867  --.-KB/s    in 0.005s
#
# 2023-06-14 02:58:28 (184 KB/s) - ‘mmseg/datasets/DubaiDataset.py’ saved [867/867]

# %%
# !rm -rf mmseg/datasets/__init__.py # 删除原有文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/__init__.py -P mmseg/datasets
# Out:
# --2023-06-14 02:59:52--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/__init__.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2620 (2.6K) [binary/octet-stream]
# Saving to: ‘mmseg/datasets/__init__.py’
#
# __init__.py         100%[===================>]   2.56K  --.-KB/s    in 0.01s
#
# 2023-06-14 02:59:53 (264 KB/s) - ‘mmseg/datasets/__init__.py’ saved [2620/2620]

# %%
# !rm -rf configs/_base_/datasets/DubaiDataset_pipeline.py
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/DubaiDataset_pipeline.py -P configs/_base_/datasets
# Out:
# --2023-06-14 08:00:47--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/DubaiDataset_pipeline.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2268 (2.2K) [binary/octet-stream]
# Saving to: ‘configs/_base_/datasets/DubaiDataset_pipeline.py’
#
# DubaiDataset_pipeli 100%[===================>]   2.21K  --.-KB/s    in 0.01s
#
# 2023-06-14 08:00:47 (193 KB/s) - ‘configs/_base_/datasets/DubaiDataset_pipeline.py’ saved [2268/2268]

# %%
# 下载模型config配置文件
# !rm -rf configs/pspnet/pspnet_r50-d8_4xb2-40k_DubaiDataset.py # 删除原有文件
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDataset.py -P configs/pspnet
# Out:
# --2023-06-14 08:03:07--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/Dubai/pspnet_r50-d8_4xb2-40k_DubaiDataset.py
# Resolving zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)... 121.36.235.132
# Connecting to zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com (zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com)|121.36.235.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 344 [binary/octet-stream]
# Saving to: ‘configs/pspnet/pspnet_r50-d8_4xb2-40k_DubaiDataset.py’
#
# pspnet_r50-d8_4xb2- 100%[===================>]     344  --.-KB/s    in 0.005s
#
# 2023-06-14 08:03:08 (70.8 KB/s) - ‘configs/pspnet/pspnet_r50-d8_4xb2-40k_DubaiDataset.py’ saved [344/344]

# %%
# 生成了 
# mmseg/datasets/WatermelonDataset.py 
# 添加了 WatermelonDataset 到 mmseg/datasets/__init__.py
# configs/_base_/datasets/WatermelonDataset_pipeline.py
# configs/pspnet/pspnet_r50-d8_4xb2-40k_WatermelonDataset.py

# %%
# !pwd
# Out:
# /workspace/openmmhomework4/mmsegmentation

# %%
# 载入config配置文件
from mmengine import Config
cfg = Config.fromfile('./configs/pspnet/pspnet_r50-d8_4xb2-40k_WatermelonDataset.py')

# %%
# 修改config文件
cfg.norm_cfg = dict(type='BN', requires_grad=True) # 只使用GPU时，BN取代SyncBN
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# modify num classes of the model in decode/auxiliary head

# 模型 decode/auxiliary 输出头，指定为类别个数
cfg.model.decode_head.num_classes = 6
cfg.model.auxiliary_head.num_classes = 6

cfg.train_dataloader.batch_size = 8

cfg.test_dataloader = cfg.val_dataloader

# 结果保存目录
cfg.work_dir = './work_dirs/WatermelonDataset'

# 训练迭代次数
cfg.train_cfg.max_iters = 3000
# 评估模型间隔
cfg.train_cfg.val_interval = 200
# 日志记录间隔
cfg.default_hooks.logger.interval = 200
# 模型权重保存间隔
cfg.default_hooks.checkpoint.interval = 200

# 随机数种子
cfg['randomness'] = dict(seed=0)

# %%
print(cfg.pretty_text)
# Out:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(64, 64))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
# ...

# %%
# 保存cfg
cfg.dump('pspnet-WatermelonDataset_20230614.py')

# %% [markdown]
# ##### 4. 训练

# %%
cfg = Config.fromfile('/workspace/openmmhomework4/mmsegmentation/pspnet-WatermelonDataset_20230614.py')

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 06/14 09:03:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.12 (default, Oct 12 2021, 13:49:34) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 2070
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.3, V11.3.109
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %%
# runner.train()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 5. 推理预测

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mmengine import Config
from mmseg.apis import init_model, inference_model, show_result_pyplot
import mmcv
import cv2

# %%
cfg = Config.fromfile('/workspace/openmmhomework4/mmsegmentation/pspnet-WatermelonDataset_20230614.py')

# 载入模型
checkpoint_path = '/workspace/openmmhomework4/mmsegmentation/work_dirs/WatermelonDataset/iter_3000.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')
# Out:
# /workspace/openmmhomework4/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /workspace/openmmhomework4/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: /workspace/openmmhomework4/mmsegmentation/work_dirs/WatermelonDataset/iter_3000.pth

# %%
img = mmcv.imread('/workspace/openmmhomework4/watermelon_test.jpg')
plt.imshow(img[::,])
plt.show()

# %%
# 语义分割
result = inference_model(model, img)

# %%
pred_mask = result.pred_sem_seg.data[0].cpu().numpy()

# %%
pred_mask.shape
# Out:
# (720, 1080)

# %%
plt.imshow(pred_mask)
plt.show()
